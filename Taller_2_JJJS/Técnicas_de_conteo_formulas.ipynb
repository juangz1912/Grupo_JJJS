# %% [markdown]
# #Variación ordinaria

# %% [markdown]
# ![2410c5_4f14ae7dc844409793720eeaa0bf01c7_mv2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Variación con repetición

# %% [markdown]
# ![2410c5_482d43f4995940e98678e95d590984b8_mv2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Permutación ordinaria

# %% [markdown]
# ![desktop_f64d6fd6-5915-4a07-8425-7104faa2fbb8.png](data:image/png;base64,...)

# %% [markdown]
# #Permutación con repetición

# %% [markdown]
# ![FormulaPermutacionesCon.png](data:image/png;base64,...)

# %% [markdown]
# #Combinación ordinaria

# %% [markdown]
# ![FormulaCombinacionesSin.png](data:image/png;base64,...)

# %% [markdown]
# #Combinación con repetición

# %% [markdown]
# ![2410c5_0ee4c86b8e1b4d6aac6541ac23ae7ec9_mv2.jpeg](data:image/jpeg;base64,...)
